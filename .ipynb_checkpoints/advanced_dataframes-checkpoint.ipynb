# %% [markdown]
# # Exercises I
#
# 1. Run python -m pip install pymysql from your terminal to install the mysql client (any folder is fine)
# 2. cd into your exercises folder for this module and run echo env.py >> .gitignore
# 3. Create a function named get_db_url. It should accept a username, hostname, password, and database name and return a url connection string formatted like in the example at the start of this lesson.
# 4. Use your function to obtain a connection to the employees database.

# %%
import pandas as pd
import numpy as np

# %%
def get_db_url(db_name):
    from env import user, host, password
    return f'mysql+pymysql://{user}:{password}@{host}/{db_name}'

# %%
sql = """
    SELECT * from departments
"""

# %%
# Called the "Connection String" because it has all the info to connect
url = get_db_url('employees')
url
# Out:
# 'mysql+pymysql://hopper_1560:ZtQEG4UaEJjR8khD2h5h8A9OUwsMjMK0@157.230.209.171/employees'

# %%
df = pd.read_sql(sql, url)
df.head()
# Out:
#   dept_no         dept_name
# 0    d009  Customer Service
# 1    d005       Development
# 2    d002           Finance
# 3    d003   Human Resources
# 4    d001         Marketing

# %% [markdown]
# 5. Once you have successfully run a query:a. Intentionally make a typo in the database url. What kind of error message do you see?b. Intentionally make an error in your SQL query. What does the error message look like?

# %% [markdown]
# 6. Read the employees and titles tables into two separate DataFrames.

# %% [markdown]
# 7. How many rows and columns do you have in each DataFrame? Is that what you expected?

# %% [markdown]
# 8. Display the summary statistics for each DataFrame.

# %% [markdown]
# 9. How many unique titles are in the titles DataFrame?

# %% [markdown]
# 10. What is the oldest date in the to_date column?

# %% [markdown]
# 11. What is the most recent date in the to_date column?

# %% [markdown]
# # Exercises II

# %% [markdown]
# ## 1. Copy the users and roles DataFrames from the examples above.

# %%
roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %%
users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %% [markdown]
# ## 2. What is the result of using a right join on the DataFrames?

# %%
users.merge(roles, left_on='id', right_on='id', how='right')
# Out:
#    id name_x  role_id     name_y
# 0   1    bob      1.0      admin
# 1   2    joe      2.0     author
# 2   3  sally      3.0   reviewer
# 3   4   adam      3.0  commenter

# %% [markdown]
# ## 3. What is the result of using an outer join on the DataFrames?

# %%
users.merge(roles, left_on='id', right_on='id', how='outer')
# Out:
#    id name_x  role_id     name_y
# 0   1    bob      1.0      admin
# 1   2    joe      2.0     author
# 2   3  sally      3.0   reviewer
# 3   4   adam      3.0  commenter
# 4   5   jane      NaN        NaN
# 5   6   mike      NaN        NaN

# %% [markdown]
# ## 4. What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %%
users = users.drop(columns='id')
roles = roles.drop(columns='id')

# %%
users
# Out:
#     name  role_id
# 0    bob      1.0
# 1    joe      2.0
# 2  sally      3.0
# 3   adam      3.0
# 4   jane      NaN
# 5   mike      NaN

# %%
roles
# Out:
#         name
# 0      admin
# 1     author
# 2   reviewer
# 3  commenter

# %%
users.merge(roles, left_on='name', right_on='name')
# Out:
# Empty DataFrame
# Columns: [name, role_id]
# Index: []

# %% [markdown]
# ## 5. Load the mpg dataset from PyDataset.

# %%
from pydataset import data

# %% [markdown]
# ## 6. Output and read the documentation for the mpg dataset.

# %%
mpg = data('mpg')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
# 234  midsize
#
# [234 rows x 11 columns]

# %%
data('mpg',show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %% [markdown]
# ## 7. How many rows and columns are in the dataset?

# %%
mpg.shape
# Out:
# (234, 11)

# %% [markdown]
# ## 8. Check out your column names and perform any cleanup you may want on them.

# %%
mpg.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %%
mpg = mpg.rename(columns=
          {'cty':'city',
          'hwy':'highway'})
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
# 234  midsize
#
# [234 rows x 11 columns]

# %% [markdown]
# ## 9. Display the summary statistics for the dataset.

# %%
mpg.describe()
# Out:
#             displ         year         cyl        city     highway
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   city          234 non-null    int64
#  8   highway       234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %% [markdown]
# ## 10. How many different manufacturers are there?

# %%
len(mpg.manufacturer.unique())
# Out:
# 15

# %% [markdown]
# ## 11. How many different models are there?

# %%
len(mpg.model.unique())
# Out:
# 38

# %% [markdown]
# ## 12. Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

# %%
mileage_difference = mpg.highway - mpg.city
mileage_difference
# Out:
# 1      11
# 2       8
# 3      11
# 4       9
# 5      10
#        ..
# 230     9
# 231     8
# 232    10
# 233     8
# 234     9
# Length: 234, dtype: int64

# %%
mpg['mileage_difference'] = mileage_difference
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class  mileage_difference
# 1    compact                  11
# 2    compact                   8
# 3    compact                  11
# 4    compact                   9
# 5    compact                  10
# ..       ...                 ...
# 230  midsize                   9
# 231  midsize                   8
# 232  midsize                  10
# 233  midsize                   8
# 234  midsize                   9
#
# [234 rows x 12 columns]

# %% [markdown]
# ## 13. Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

# %%
average_mileage = mpg[['city','highway']].mean(axis=1)
average_mileage
# Out:
# 1      23.5
# 2      25.0
# 3      25.5
# 4      25.5
# 5      21.0
#        ...
# 230    23.5
# 231    25.0
# 232    21.0
# 233    22.0
# 234    21.5
# Length: 234, dtype: float64

# %%
mpg['average_mileage'] = average_mileage
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class  mileage_difference  is_automatic  average_mileage
# 1    compact                  11          True             23.5
# 2    compact                   8         False             25.0
# 3    compact                  11         False             25.5
# 4    compact                   9          True             25.5
# 5    compact                  10          True             21.0
# ..       ...                 ...           ...              ...
# 230  midsize                   9          True             23.5
# 231  midsize                   8         False             25.0
# 232  midsize                  10          True             21.0
# 233  midsize                   8         False             22.0
# 234  midsize                   9          True             21.5
#
# [234 rows x 14 columns]

# %% [markdown]
# ## 14. Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# %%
is_automatic = mpg.trans.str.contains('auto')
is_automatic
# Out:
# 1       True
# 2      False
# 3      False
# 4       True
# 5       True
#        ...
# 230     True
# 231    False
# 232     True
# 233    False
# 234     True
# Name: trans, Length: 234, dtype: bool

# %%
mpg['is_automatic'] = is_automatic
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class  mileage_difference  is_automatic  average_mileage
# 1    compact                  11          True             23.5
# 2    compact                   8         False             25.0
# 3    compact                  11         False             25.5
# 4    compact                   9          True             25.5
# 5    compact                  10          True             21.0
# ..       ...                 ...           ...              ...
# 230  midsize                   9          True             23.5
# 231  midsize                   8         False             25.0
# 232  midsize                  10          True             21.0
# 233  midsize                   8         False             22.0
# 234  midsize                   9          True             21.5
#
# [234 rows x 14 columns]

# %% [markdown]
# ## 15. Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

# %%
mpg[mpg.average_mileage == mpg.average_mileage.max()]
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  city  highway  \
# 222   volkswagen  new beetle    1.9  1999    4  manual(m5)   f    35       44
#
#     fl       class  mileage_difference  is_automatic  average_mileage
# 222  d  subcompact                   9         False             39.5

# %% [markdown]
# ## 16. Do automatic or manual cars have better miles per gallon

# %%
mpg_auto = mpg[mpg.trans.str.contains('auto')]
mpg_auto
# Out:
#     manufacturer                   model  displ  year  cyl     trans drv  \
# 1           audi                      a4    1.8  1999    4  auto(l5)   f
# 4           audi                      a4    2.0  2008    4  auto(av)   f
# 5           audi                      a4    2.8  1999    6  auto(l5)   f
# 7           audi                      a4    3.1  2008    6  auto(av)   f
# 9           audi              a4 quattro    1.8  1999    4  auto(l5)   4
# 11          audi              a4 quattro    2.0  2008    4  auto(s6)   4
# 12          audi              a4 quattro    2.8  1999    6  auto(l5)   4
# 14          audi              a4 quattro    3.1  2008    6  auto(s6)   4
# 16          audi              a6 quattro    2.8  1999    6  auto(l5)   4
# 17          audi              a6 quattro    3.1  2008    6  auto(s6)   4
# 18          audi              a6 quattro    4.2  2008    8  auto(s6)   4
# 19     chevrolet      c1500 suburban 2wd    5.3  2008    8  auto(l4)   r
# 20     chevrolet      c1500 suburban 2wd    5.3  2008    8  auto(l4)   r
# 21     chevrolet      c1500 suburban 2wd    5.3  2008    8  auto(l4)   r
# 22     chevrolet      c1500 suburban 2wd    5.7  1999    8  auto(l4)   r
# 23     chevrolet      c1500 suburban 2wd    6.0  2008    8  auto(l4)   r
# 25     chevrolet                corvette    5.7  1999    8  auto(l4)   r
# 27     chevrolet                corvette    6.2  2008    8  auto(s6)   r
# 29     chevrolet         k1500 tahoe 4wd    5.3  2008    8  auto(l4)   4
# 30     chevrolet         k1500 tahoe 4wd    5.3  2008    8  auto(l4)   4
# 31     chevrolet         k1500 tahoe 4wd    5.7  1999    8  auto(l4)   4
# 32     chevrolet         k1500 tahoe 4wd    6.5  1999    8  auto(l4)   4
# 33     chevrolet                  malibu    2.4  1999    4  auto(l4)   f
# 34     chevrolet                  malibu    2.4  2008    4  auto(l4)   f
# 35     chevrolet                  malibu    3.1  1999    6  auto(l4)   f
# 36     chevrolet                  malibu    3.5  2008    6  auto(l4)   f
# 37     chevrolet                  malibu    3.6  2008    6  auto(s6)   f
# 38         dodge             caravan 2wd    2.4  1999    4  auto(l3)   f
# 39         dodge             caravan 2wd    3.0  1999    6  auto(l4)   f
# 40         dodge             caravan 2wd    3.3  1999    6  auto(l4)   f
# 41         dodge             caravan 2wd    3.3  1999    6  auto(l4)   f
# 42         dodge             caravan 2wd    3.3  2008    6  auto(l4)   f
# 43         dodge             caravan 2wd    3.3  2008    6  auto(l4)   f
# 44         dodge             caravan 2wd    3.3  2008    6  auto(l4)   f
# 45         dodge             caravan 2wd    3.8  1999    6  auto(l4)   f
# 46         dodge             caravan 2wd    3.8  1999    6  auto(l4)   f
# 47         dodge             caravan 2wd    3.8  2008    6  auto(l6)   f
# 48         dodge             caravan 2wd    4.0  2008    6  auto(l6)   f
# 50         dodge       dakota pickup 4wd    3.7  2008    6  auto(l4)   4
# 51         dodge       dakota pickup 4wd    3.9  1999    6  auto(l4)   4
# 53         dodge       dakota pickup 4wd    4.7  2008    8  auto(l5)   4
# 54         dodge       dakota pickup 4wd    4.7  2008    8  auto(l5)   4
# 55         dodge       dakota pickup 4wd    4.7  2008    8  auto(l5)   4
# 57         dodge       dakota pickup 4wd    5.2  1999    8  auto(l4)   4
# 58         dodge             durango 4wd    3.9  1999    6  auto(l4)   4
# 59         dodge             durango 4wd    4.7  2008    8  auto(l5)   4
# 60         dodge             durango 4wd    4.7  2008    8  auto(l5)   4
# 61         dodge             durango 4wd    4.7  2008    8  auto(l5)   4
# 62         dodge             durango 4wd    5.2  1999    8  auto(l4)   4
# 63         dodge             durango 4wd    5.7  2008    8  auto(l5)   4
# 64         dodge             durango 4wd    5.9  1999    8  auto(l4)   4
# 66         dodge     ram 1500 pickup 4wd    4.7  2008    8  auto(l5)   4
# 67         dodge     ram 1500 pickup 4wd    4.7  2008    8  auto(l5)   4
# 68         dodge     ram 1500 pickup 4wd    4.7  2008    8  auto(l5)   4
# 71         dodge     ram 1500 pickup 4wd    5.2  1999    8  auto(l4)   4
# 73         dodge     ram 1500 pickup 4wd    5.7  2008    8  auto(l5)   4
# 74         dodge     ram 1500 pickup 4wd    5.9  1999    8  auto(l4)   4
# 75          ford          expedition 2wd    4.6  1999    8  auto(l4)   r
# 76          ford          expedition 2wd    5.4  1999    8  auto(l4)   r
# 77          ford          expedition 2wd    5.4  2008    8  auto(l6)   r
# 78          ford            explorer 4wd    4.0  1999    6  auto(l5)   4
# 80          ford            explorer 4wd    4.0  1999    6  auto(l5)   4
# 81          ford            explorer 4wd    4.0  2008    6  auto(l5)   4
# 82          ford            explorer 4wd    4.6  2008    8  auto(l6)   4
# 83          ford            explorer 4wd    5.0  1999    8  auto(l4)   4
# 84          ford         f150 pickup 4wd    4.2  1999    6  auto(l4)   4
# 87          ford         f150 pickup 4wd    4.6  1999    8  auto(l4)   4
# 88          ford         f150 pickup 4wd    4.6  2008    8  auto(l4)   4
# 89          ford         f150 pickup 4wd    5.4  1999    8  auto(l4)   4
# 90          ford         f150 pickup 4wd    5.4  2008    8  auto(l4)   4
# 92          ford                 mustang    3.8  1999    6  auto(l4)   r
# 94          ford                 mustang    4.0  2008    6  auto(l5)   r
# 95          ford                 mustang    4.6  1999    8  auto(l4)   r
# 98          ford                 mustang    4.6  2008    8  auto(l5)   r
# 101        honda                   civic    1.6  1999    4  auto(l4)   f
# 104        honda                   civic    1.6  1999    4  auto(l4)   f
# 106        honda                   civic    1.8  2008    4  auto(l5)   f
# 107        honda                   civic    1.8  2008    4  auto(l5)   f
# 109      hyundai                  sonata    2.4  1999    4  auto(l4)   f
# 111      hyundai                  sonata    2.4  2008    4  auto(l4)   f
# 113      hyundai                  sonata    2.5  1999    6  auto(l4)   f
# 115      hyundai                  sonata    3.3  2008    6  auto(l5)   f
# 116      hyundai                 tiburon    2.0  1999    4  auto(l4)   f
# 119      hyundai                 tiburon    2.0  2008    4  auto(l4)   f
# 120      hyundai                 tiburon    2.7  2008    6  auto(l4)   f
# 123         jeep      grand cherokee 4wd    3.0  2008    6  auto(l5)   4
# 124         jeep      grand cherokee 4wd    3.7  2008    6  auto(l5)   4
# 125         jeep      grand cherokee 4wd    4.0  1999    6  auto(l4)   4
# 126         jeep      grand cherokee 4wd    4.7  1999    8  auto(l4)   4
# 127         jeep      grand cherokee 4wd    4.7  2008    8  auto(l5)   4
# 128         jeep      grand cherokee 4wd    4.7  2008    8  auto(l5)   4
# 129         jeep      grand cherokee 4wd    5.7  2008    8  auto(l5)   4
# 130         jeep      grand cherokee 4wd    6.1  2008    8  auto(l5)   4
# 131   land rover             range rover    4.0  1999    8  auto(l4)   4
# 132   land rover             range rover    4.2  2008    8  auto(s6)   4
# 133   land rover             range rover    4.4  2008    8  auto(s6)   4
# 134   land rover             range rover    4.6  1999    8  auto(l4)   4
# 135      lincoln           navigator 2wd    5.4  1999    8  auto(l4)   r
# 136      lincoln           navigator 2wd    5.4  1999    8  auto(l4)   r
# 137      lincoln           navigator 2wd    5.4  2008    8  auto(l6)   r
# 138      mercury         mountaineer 4wd    4.0  1999    6  auto(l5)   4
# 139      mercury         mountaineer 4wd    4.0  2008    6  auto(l5)   4
# 140      mercury         mountaineer 4wd    4.6  2008    8  auto(l6)   4
# 141      mercury         mountaineer 4wd    5.0  1999    8  auto(l4)   4
# 143       nissan                  altima    2.4  1999    4  auto(l4)   f
# 144       nissan                  altima    2.5  2008    4  auto(av)   f
# 147       nissan                  altima    3.5  2008    6  auto(av)   f
# 148       nissan                  maxima    3.0  1999    6  auto(l4)   f
# 150       nissan                  maxima    3.5  2008    6  auto(av)   f
# 151       nissan          pathfinder 4wd    3.3  1999    6  auto(l4)   4
# 153       nissan          pathfinder 4wd    4.0  2008    6  auto(l5)   4
# 154       nissan          pathfinder 4wd    5.6  2008    8  auto(s5)   4
# 155      pontiac              grand prix    3.1  1999    6  auto(l4)   f
# 156      pontiac              grand prix    3.8  1999    6  auto(l4)   f
# 157      pontiac              grand prix    3.8  1999    6  auto(l4)   f
# 158      pontiac              grand prix    3.8  2008    6  auto(l4)   f
# 159      pontiac              grand prix    5.3  2008    8  auto(s4)   f
# 161       subaru            forester awd    2.5  1999    4  auto(l4)   4
# 164       subaru            forester awd    2.5  2008    4  auto(l4)   4
# 165       subaru            forester awd    2.5  2008    4  auto(l4)   4
# 166       subaru             impreza awd    2.2  1999    4  auto(l4)   4
# 169       subaru             impreza awd    2.5  1999    4  auto(l4)   4
# 170       subaru             impreza awd    2.5  2008    4  auto(s4)   4
# 171       subaru             impreza awd    2.5  2008    4  auto(s4)   4
# 175       toyota             4runner 4wd    2.7  1999    4  auto(l4)   4
# 176       toyota             4runner 4wd    3.4  1999    6  auto(l4)   4
# 178       toyota             4runner 4wd    4.0  2008    6  auto(l5)   4
# 179       toyota             4runner 4wd    4.7  2008    8  auto(l5)   4
# 181       toyota                   camry    2.2  1999    4  auto(l4)   f
# 183       toyota                   camry    2.4  2008    4  auto(l5)   f
# 184       toyota                   camry    3.0  1999    6  auto(l4)   f
# 186       toyota                   camry    3.5  2008    6  auto(s6)   f
# 187       toyota            camry solara    2.2  1999    4  auto(l4)   f
# 190       toyota            camry solara    2.4  2008    4  auto(s5)   f
# 191       toyota            camry solara    3.0  1999    6  auto(l4)   f
# 193       toyota            camry solara    3.3  2008    6  auto(s5)   f
# 194       toyota                 corolla    1.8  1999    4  auto(l3)   f
# 195       toyota                 corolla    1.8  1999    4  auto(l4)   f
# 198       toyota                 corolla    1.8  2008    4  auto(l4)   f
# 199       toyota  land cruiser wagon 4wd    4.7  1999    8  auto(l4)   4
# 200       toyota  land cruiser wagon 4wd    5.7  2008    8  auto(s6)   4
# 202       toyota       toyota tacoma 4wd    2.7  1999    4  auto(l4)   4
# 205       toyota       toyota tacoma 4wd    3.4  1999    6  auto(l4)   4
# 207       toyota       toyota tacoma 4wd    4.0  2008    6  auto(l5)   4
# 209   volkswagen                     gti    2.0  1999    4  auto(l4)   f
# 211   volkswagen                     gti    2.0  2008    4  auto(s6)   f
# 215   volkswagen                   jetta    2.0  1999    4  auto(l4)   f
# 216   volkswagen                   jetta    2.0  2008    4  auto(s6)   f
# 218   volkswagen                   jetta    2.5  2008    5  auto(s6)   f
# 220   volkswagen                   jetta    2.8  1999    6  auto(l4)   f
# 223   volkswagen              new beetle    1.9  1999    4  auto(l4)   f
# 225   volkswagen              new beetle    2.0  1999    4  auto(l4)   f
# 227   volkswagen              new beetle    2.5  2008    5  auto(s6)   f
# 229   volkswagen                  passat    1.8  1999    4  auto(l5)   f
# 230   volkswagen                  passat    2.0  2008    4  auto(s6)   f
# 232   volkswagen                  passat    2.8  1999    6  auto(l5)   f
# 234   volkswagen                  passat    3.6  2008    6  auto(s6)   f
#
#      city  highway fl       class  mileage_difference  is_automatic  \
# 1      18       29  p     compact                  11          True
# 4      21       30  p     compact                   9          True
# 5      16       26  p     compact                  10          True
# 7      18       27  p     compact                   9          True
# 9      16       25  p     compact                   9          True
# 11     19       27  p     compact                   8          True
# 12     15       25  p     compact                  10          True
# 14     17       25  p     compact                   8          True
# 16     15       24  p     midsize                   9          True
# 17     17       25  p     midsize                   8          True
# 18     16       23  p     midsize                   7          True
# 19     14       20  r         suv                   6          True
# 20     11       15  e         suv                   4          True
# 21     14       20  r         suv                   6          True
# 22     13       17  r         suv                   4          True
# 23     12       17  r         suv                   5          True
# 25     15       23  p     2seater                   8          True
# 27     15       25  p     2seater                  10          True
# 29     14       19  r         suv                   5          True
# 30     11       14  e         suv                   3          True
# 31     11       15  r         suv                   4          True
# 32     14       17  d         suv                   3          True
# 33     19       27  r     midsize                   8          True
# 34     22       30  r     midsize                   8          True
# 35     18       26  r     midsize                   8          True
# 36     18       29  r     midsize                  11          True
# 37     17       26  r     midsize                   9          True
# 38     18       24  r     minivan                   6          True
# 39     17       24  r     minivan                   7          True
# 40     16       22  r     minivan                   6          True
# 41     16       22  r     minivan                   6          True
# 42     17       24  r     minivan                   7          True
# 43     17       24  r     minivan                   7          True
# 44     11       17  e     minivan                   6          True
# 45     15       22  r     minivan                   7          True
# 46     15       21  r     minivan                   6          True
# 47     16       23  r     minivan                   7          True
# 48     16       23  r     minivan                   7          True
# 50     14       18  r      pickup                   4          True
# 51     13       17  r      pickup                   4          True
# 53     14       19  r      pickup                   5          True
# 54     14       19  r      pickup                   5          True
# 55      9       12  e      pickup                   3          True
# 57     11       15  r      pickup                   4          True
# 58     13       17  r         suv                   4          True
# 59     13       17  r         suv                   4          True
# 60      9       12  e         suv                   3          True
# 61     13       17  r         suv                   4          True
# 62     11       16  r         suv                   5          True
# 63     13       18  r         suv                   5          True
# 64     11       15  r         suv                   4          True
# 66      9       12  e      pickup                   3          True
# 67     13       17  r      pickup                   4          True
# 68     13       17  r      pickup                   4          True
# 71     11       15  r      pickup                   4          True
# 73     13       17  r      pickup                   4          True
# 74     11       15  r      pickup                   4          True
# 75     11       17  r         suv                   6          True
# 76     11       17  r         suv                   6          True
# 77     12       18  r         suv                   6          True
# 78     14       17  r         suv                   3          True
# 80     14       17  r         suv                   3          True
# 81     13       19  r         suv                   6          True
# 82     13       19  r         suv                   6          True
# 83     13       17  r         suv                   4          True
# 84     14       17  r      pickup                   3          True
# 87     13       16  r      pickup                   3          True
# 88     13       17  r      pickup                   4          True
# 89     11       15  r      pickup                   4          True
# 90     13       17  r      pickup                   4          True
# 92     18       25  r  subcompact                   7          True
# 94     16       24  r  subcompact                   8          True
# 95     15       21  r  subcompact                   6          True
# 98     15       22  r  subcompact                   7          True
# 101    24       32  r  subcompact                   8          True
# 104    24       32  r  subcompact                   8          True
# 106    25       36  r  subcompact                  11          True
# 107    24       36  c  subcompact                  12          True
# 109    18       26  r     midsize                   8          True
# 111    21       30  r     midsize                   9          True
# 113    18       26  r     midsize                   8          True
# 115    19       28  r     midsize                   9          True
# 116    19       26  r  subcompact                   7          True
# 119    20       27  r  subcompact                   7          True
# 120    17       24  r  subcompact                   7          True
# 123    17       22  d         suv                   5          True
# 124    15       19  r         suv                   4          True
# 125    15       20  r         suv                   5          True
# 126    14       17  r         suv                   3          True
# 127     9       12  e         suv                   3          True
# 128    14       19  r         suv                   5          True
# 129    13       18  r         suv                   5          True
# 130    11       14  p         suv                   3          True
# 131    11       15  p         suv                   4          True
# 132    12       18  r         suv                   6          True
# 133    12       18  r         suv                   6          True
# 134    11       15  p         suv                   4          True
# 135    11       17  r         suv                   6          True
# 136    11       16  p         suv                   5          True
# 137    12       18  r         suv                   6          True
# 138    14       17  r         suv                   3          True
# 139    13       19  r         suv                   6          True
# 140    13       19  r         suv                   6          True
# 141    13       17  r         suv                   4          True
# 143    19       27  r     compact                   8          True
# 144    23       31  r     midsize                   8          True
# 147    19       26  p     midsize                   7          True
# 148    18       26  r     midsize                   8          True
# 150    19       25  p     midsize                   6          True
# 151    14       17  r         suv                   3          True
# 153    14       20  p         suv                   6          True
# 154    12       18  p         suv                   6          True
# 155    18       26  r     midsize                   8          True
# 156    16       26  p     midsize                  10          True
# 157    17       27  r     midsize                  10          True
# 158    18       28  r     midsize                  10          True
# 159    16       25  p     midsize                   9          True
# 161    18       24  r         suv                   6          True
# 164    20       26  r         suv                   6          True
# 165    18       23  p         suv                   5          True
# 166    21       26  r  subcompact                   5          True
# 169    19       26  r  subcompact                   7          True
# 170    20       25  p     compact                   5          True
# 171    20       27  r     compact                   7          True
# 175    16       20  r         suv                   4          True
# 176    15       19  r         suv                   4          True
# 178    16       20  r         suv                   4          True
# 179    14       17  r         suv                   3          True
# 181    21       27  r     midsize                   6          True
# 183    21       31  r     midsize                  10          True
# 184    18       26  r     midsize                   8          True
# 186    19       28  r     midsize                   9          True
# 187    21       27  r     compact                   6          True
# 190    22       31  r     compact                   9          True
# 191    18       26  r     compact                   8          True
# 193    18       27  r     compact                   9          True
# 194    24       30  r     compact                   6          True
# 195    24       33  r     compact                   9          True
# 198    26       35  r     compact                   9          True
# 199    11       15  r         suv                   4          True
# 200    13       18  r         suv                   5          True
# 202    16       20  r      pickup                   4          True
# 205    15       19  r      pickup                   4          True
# 207    16       20  r      pickup                   4          True
# 209    19       26  r     compact                   7          True
# 211    22       29  p     compact                   7          True
# 215    19       26  r     compact                   7          True
# 216    22       29  p     compact                   7          True
# 218    21       29  r     compact                   8          True
# 220    16       23  r     compact                   7          True
# 223    29       41  d  subcompact                  12          True
# 225    19       26  r  subcompact                   7          True
# 227    20       29  r  subcompact                   9          True
# 229    18       29  p     midsize                  11          True
# 230    19       28  p     midsize                   9          True
# 232    16       26  p     midsize                  10          True
# 234    17       26  p     midsize                   9          True
#
#      average_mileage
# 1               23.5
# 4               25.5
# 5               21.0
# 7               22.5
# 9               20.5
# 11              23.0
# 12              20.0
# 14              21.0
# 16              19.5
# 17              21.0
# 18              19.5
# 19              17.0
# 20              13.0
# 21              17.0
# 22              15.0
# 23              14.5
# 25              19.0
# 27              20.0
# 29              16.5
# 30              12.5
# 31              13.0
# 32              15.5
# 33              23.0
# 34              26.0
# 35              22.0
# 36              23.5
# 37              21.5
# 38              21.0
# 39              20.5
# 40              19.0
# 41              19.0
# 42              20.5
# 43              20.5
# 44              14.0
# 45              18.5
# 46              18.0
# 47              19.5
# 48              19.5
# 50              16.0
# 51              15.0
# 53              16.5
# 54              16.5
# 55              10.5
# 57              13.0
# 58              15.0
# 59              15.0
# 60              10.5
# 61              15.0
# 62              13.5
# 63              15.5
# 64              13.0
# 66              10.5
# 67              15.0
# 68              15.0
# 71              13.0
# 73              15.0
# 74              13.0
# 75              14.0
# 76              14.0
# 77              15.0
# 78              15.5
# 80              15.5
# 81              16.0
# 82              16.0
# 83              15.0
# 84              15.5
# 87              14.5
# 88              15.0
# 89              13.0
# 90              15.0
# 92              21.5
# 94              20.0
# 95              18.0
# 98              18.5
# 101             28.0
# 104             28.0
# 106             30.5
# 107             30.0
# 109             22.0
# 111             25.5
# 113             22.0
# 115             23.5
# 116             22.5
# 119             23.5
# 120             20.5
# 123             19.5
# 124             17.0
# 125             17.5
# 126             15.5
# 127             10.5
# 128             16.5
# 129             15.5
# 130             12.5
# 131             13.0
# 132             15.0
# 133             15.0
# 134             13.0
# 135             14.0
# 136             13.5
# 137             15.0
# 138             15.5
# 139             16.0
# 140             16.0
# 141             15.0
# 143             23.0
# 144             27.0
# 147             22.5
# 148             22.0
# 150             22.0
# 151             15.5
# 153             17.0
# 154             15.0
# 155             22.0
# 156             21.0
# 157             22.0
# 158             23.0
# 159             20.5
# 161             21.0
# 164             23.0
# 165             20.5
# 166             23.5
# 169             22.5
# 170             22.5
# 171             23.5
# 175             18.0
# 176             17.0
# 178             18.0
# 179             15.5
# 181             24.0
# 183             26.0
# 184             22.0
# 186             23.5
# 187             24.0
# 190             26.5
# 191             22.0
# 193             22.5
# 194             27.0
# 195             28.5
# 198             30.5
# 199             13.0
# 200             15.5
# 202             18.0
# 205             17.0
# 207             18.0
# 209             22.5
# 211             25.5
# 215             22.5
# 216             25.5
# 218             25.0
# 220             19.5
# 223             35.0
# 225             22.5
# 227             24.5
# 229             23.5
# 230             23.5
# 232             21.0
# 234             21.5

# %%
mpg_auto.average_mileage.mean()
# Out:
# 19.130573248407643

# %%
mpg_manual = mpg[mpg.trans.str.contains('manual')]
mpg_manual
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  city  \
# 2           audi                   a4    1.8  1999    4  manual(m5)   f    21
# 3           audi                   a4    2.0  2008    4  manual(m6)   f    20
# 6           audi                   a4    2.8  1999    6  manual(m5)   f    18
# 8           audi           a4 quattro    1.8  1999    4  manual(m5)   4    18
# 10          audi           a4 quattro    2.0  2008    4  manual(m6)   4    20
# 13          audi           a4 quattro    2.8  1999    6  manual(m5)   4    17
# 15          audi           a4 quattro    3.1  2008    6  manual(m6)   4    15
# 24     chevrolet             corvette    5.7  1999    8  manual(m6)   r    16
# 26     chevrolet             corvette    6.2  2008    8  manual(m6)   r    16
# 28     chevrolet             corvette    7.0  2008    8  manual(m6)   r    15
# 49         dodge    dakota pickup 4wd    3.7  2008    6  manual(m6)   4    15
# 52         dodge    dakota pickup 4wd    3.9  1999    6  manual(m5)   4    14
# 56         dodge    dakota pickup 4wd    5.2  1999    8  manual(m5)   4    11
# 65         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    12
# 69         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    12
# 70         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
# 72         dodge  ram 1500 pickup 4wd    5.2  1999    8  manual(m5)   4    11
# 79          ford         explorer 4wd    4.0  1999    6  manual(m5)   4    15
# 85          ford      f150 pickup 4wd    4.2  1999    6  manual(m5)   4    14
# 86          ford      f150 pickup 4wd    4.6  1999    8  manual(m5)   4    13
# 91          ford              mustang    3.8  1999    6  manual(m5)   r    18
# 93          ford              mustang    4.0  2008    6  manual(m5)   r    17
# 96          ford              mustang    4.6  1999    8  manual(m5)   r    15
# 97          ford              mustang    4.6  2008    8  manual(m5)   r    15
# 99          ford              mustang    5.4  2008    8  manual(m6)   r    14
# 100        honda                civic    1.6  1999    4  manual(m5)   f    28
# 102        honda                civic    1.6  1999    4  manual(m5)   f    25
# 103        honda                civic    1.6  1999    4  manual(m5)   f    23
# 105        honda                civic    1.8  2008    4  manual(m5)   f    26
# 108        honda                civic    2.0  2008    4  manual(m6)   f    21
# 110      hyundai               sonata    2.4  1999    4  manual(m5)   f    18
# 112      hyundai               sonata    2.4  2008    4  manual(m5)   f    21
# 114      hyundai               sonata    2.5  1999    6  manual(m5)   f    18
# 117      hyundai              tiburon    2.0  1999    4  manual(m5)   f    19
# 118      hyundai              tiburon    2.0  2008    4  manual(m5)   f    20
# 121      hyundai              tiburon    2.7  2008    6  manual(m6)   f    16
# 122      hyundai              tiburon    2.7  2008    6  manual(m5)   f    17
# 142       nissan               altima    2.4  1999    4  manual(m5)   f    21
# 145       nissan               altima    2.5  2008    4  manual(m6)   f    23
# 146       nissan               altima    3.5  2008    6  manual(m6)   f    19
# 149       nissan               maxima    3.0  1999    6  manual(m5)   f    19
# 152       nissan       pathfinder 4wd    3.3  1999    6  manual(m5)   4    15
# 160       subaru         forester awd    2.5  1999    4  manual(m5)   4    18
# 162       subaru         forester awd    2.5  2008    4  manual(m5)   4    20
# 163       subaru         forester awd    2.5  2008    4  manual(m5)   4    19
# 167       subaru          impreza awd    2.2  1999    4  manual(m5)   4    19
# 168       subaru          impreza awd    2.5  1999    4  manual(m5)   4    19
# 172       subaru          impreza awd    2.5  2008    4  manual(m5)   4    19
# 173       subaru          impreza awd    2.5  2008    4  manual(m5)   4    20
# 174       toyota          4runner 4wd    2.7  1999    4  manual(m5)   4    15
# 177       toyota          4runner 4wd    3.4  1999    6  manual(m5)   4    15
# 180       toyota                camry    2.2  1999    4  manual(m5)   f    21
# 182       toyota                camry    2.4  2008    4  manual(m5)   f    21
# 185       toyota                camry    3.0  1999    6  manual(m5)   f    18
# 188       toyota         camry solara    2.2  1999    4  manual(m5)   f    21
# 189       toyota         camry solara    2.4  2008    4  manual(m5)   f    21
# 192       toyota         camry solara    3.0  1999    6  manual(m5)   f    18
# 196       toyota              corolla    1.8  1999    4  manual(m5)   f    26
# 197       toyota              corolla    1.8  2008    4  manual(m5)   f    28
# 201       toyota    toyota tacoma 4wd    2.7  1999    4  manual(m5)   4    15
# 203       toyota    toyota tacoma 4wd    2.7  2008    4  manual(m5)   4    17
# 204       toyota    toyota tacoma 4wd    3.4  1999    6  manual(m5)   4    15
# 206       toyota    toyota tacoma 4wd    4.0  2008    6  manual(m6)   4    15
# 208   volkswagen                  gti    2.0  1999    4  manual(m5)   f    21
# 210   volkswagen                  gti    2.0  2008    4  manual(m6)   f    21
# 212   volkswagen                  gti    2.8  1999    6  manual(m5)   f    17
# 213   volkswagen                jetta    1.9  1999    4  manual(m5)   f    33
# 214   volkswagen                jetta    2.0  1999    4  manual(m5)   f    21
# 217   volkswagen                jetta    2.0  2008    4  manual(m6)   f    21
# 219   volkswagen                jetta    2.5  2008    5  manual(m5)   f    21
# 221   volkswagen                jetta    2.8  1999    6  manual(m5)   f    17
# 222   volkswagen           new beetle    1.9  1999    4  manual(m5)   f    35
# 224   volkswagen           new beetle    2.0  1999    4  manual(m5)   f    21
# 226   volkswagen           new beetle    2.5  2008    5  manual(m5)   f    20
# 228   volkswagen               passat    1.8  1999    4  manual(m5)   f    21
# 231   volkswagen               passat    2.0  2008    4  manual(m6)   f    21
# 233   volkswagen               passat    2.8  1999    6  manual(m5)   f    18
#
#      highway fl       class  mileage_difference  is_automatic  average_mileage
# 2         29  p     compact                   8         False             25.0
# 3         31  p     compact                  11         False             25.5
# 6         26  p     compact                   8         False             22.0
# 8         26  p     compact                   8         False             22.0
# 10        28  p     compact                   8         False             24.0
# 13        25  p     compact                   8         False             21.0
# 15        25  p     compact                  10         False             20.0
# 24        26  p     2seater                  10         False             21.0
# 26        26  p     2seater                  10         False             21.0
# 28        24  p     2seater                   9         False             19.5
# 49        19  r      pickup                   4         False             17.0
# 52        17  r      pickup                   3         False             15.5
# 56        17  r      pickup                   6         False             14.0
# 65        16  r      pickup                   4         False             14.0
# 69        16  r      pickup                   4         False             14.0
# 70        12  e      pickup                   3         False             10.5
# 72        16  r      pickup                   5         False             13.5
# 79        19  r         suv                   4         False             17.0
# 85        17  r      pickup                   3         False             15.5
# 86        16  r      pickup                   3         False             14.5
# 91        26  r  subcompact                   8         False             22.0
# 93        26  r  subcompact                   9         False             21.5
# 96        22  r  subcompact                   7         False             18.5
# 97        23  r  subcompact                   8         False             19.0
# 99        20  p  subcompact                   6         False             17.0
# 100       33  r  subcompact                   5         False             30.5
# 102       32  r  subcompact                   7         False             28.5
# 103       29  p  subcompact                   6         False             26.0
# 105       34  r  subcompact                   8         False             30.0
# 108       29  p  subcompact                   8         False             25.0
# 110       27  r     midsize                   9         False             22.5
# 112       31  r     midsize                  10         False             26.0
# 114       26  r     midsize                   8         False             22.0
# 117       29  r  subcompact                  10         False             24.0
# 118       28  r  subcompact                   8         False             24.0
# 121       24  r  subcompact                   8         False             20.0
# 122       24  r  subcompact                   7         False             20.5
# 142       29  r     compact                   8         False             25.0
# 145       32  r     midsize                   9         False             27.5
# 146       27  p     midsize                   8         False             23.0
# 149       25  r     midsize                   6         False             22.0
# 152       17  r         suv                   2         False             16.0
# 160       25  r         suv                   7         False             21.5
# 162       27  r         suv                   7         False             23.5
# 163       25  p         suv                   6         False             22.0
# 167       26  r  subcompact                   7         False             22.5
# 168       26  r  subcompact                   7         False             22.5
# 172       25  p     compact                   6         False             22.0
# 173       27  r     compact                   7         False             23.5
# 174       20  r         suv                   5         False             17.5
# 177       17  r         suv                   2         False             16.0
# 180       29  r     midsize                   8         False             25.0
# 182       31  r     midsize                  10         False             26.0
# 185       26  r     midsize                   8         False             22.0
# 188       29  r     compact                   8         False             25.0
# 189       31  r     compact                  10         False             26.0
# 192       26  r     compact                   8         False             22.0
# 196       35  r     compact                   9         False             30.5
# 197       37  r     compact                   9         False             32.5
# 201       20  r      pickup                   5         False             17.5
# 203       22  r      pickup                   5         False             19.5
# 204       17  r      pickup                   2         False             16.0
# 206       18  r      pickup                   3         False             16.5
# 208       29  r     compact                   8         False             25.0
# 210       29  p     compact                   8         False             25.0
# 212       24  r     compact                   7         False             20.5
# 213       44  d     compact                  11         False             38.5
# 214       29  r     compact                   8         False             25.0
# 217       29  p     compact                   8         False             25.0
# 219       29  r     compact                   8         False             25.0
# 221       24  r     compact                   7         False             20.5
# 222       44  d  subcompact                   9         False             39.5
# 224       29  r  subcompact                   8         False             25.0
# 226       28  r  subcompact                   8         False             24.0
# 228       29  p     midsize                   8         False             25.0
# 231       29  p     midsize                   8         False             25.0
# 233       26  p     midsize                   8         False             22.0

# %%
mpg_manual.average_mileage.mean()
# Out:
# 22.227272727272727

# %%
# Exercise III

# %%
chipotle = data('chipotle')
chipotle
# Out:
# Did you mean:
# Chile, Chirot, Cowles, hirose, cities, Hitters, shuttle, pottery, Pottery, alcohol, coleman

# %% [markdown]
# ## 1. Use your get_db_url function to help you explore the data from the chipotle database.

# %%
def get_db_url(db_name):
    from env import user, host, password
    return f'mysql+pymysql://{user}:{password}@{host}/{db_name}'

# %%
sql = """
    SELECT * from orders
"""

# %%
url = get_db_url('chipotle')
url
# Out:
# 'mysql+pymysql://hopper_1560:ZtQEG4UaEJjR8khD2h5h8A9OUwsMjMK0@157.230.209.171/chipotle'

# %%
df = pd.read_sql(sql, url)
df.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98

# %% [markdown]
# ## 2. What is the total price for each order?

# %%
df['item_price'] = df.item_price.str.replace('$','').astype('float')
df
# Out:
# <ipython-input-140-d2fa8e492246>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['item_price'] = df.item_price.str.replace('$','').astype('float')
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# 0                                                                                   nan
# 1                                                                          [Clementine]
# 2                                                                               [Apple]
# 3                                                                                   nan
# 4            [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
# ...                                                                                 ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour Cream, Cheese, Lettuce, Guacamole]]
# 4618               [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese, Lettuce, Guacamole]]
# 4619         [Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Guacamole, Lettuce]]
# 4620                                 [Fresh Tomato Salsa, [Fajita Vegetables, Lettuce]]
# 4621                    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Lettuce]]
#
#       item_price
# 0           2.39
# 1           3.39
# 2           3.39
# 3           2.39
# 4          16.98
# ...          ...
# 4617       11.75
# 4618       11.75
# 4619       11.25
# 4620        8.75
# 4621        8.75
#
# [4622 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  4622 non-null   int64
#  1   order_id            4622 non-null   int64
#  2   quantity            4622 non-null   int64
#  3   item_name           4622 non-null   object
#  4   choice_description  4622 non-null   object
#  5   item_price          4622 non-null   float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 216.8+ KB

# %%
df.groupby('order_id').item_price.sum()
# Out:
# order_id
# 1       11.56
# 2       16.98
# 3       12.67
# 4       21.00
# 5       13.70
#         ...
# 1830    23.00
# 1831    12.90
# 1832    13.20
# 1833    23.50
# 1834    28.75
# Name: item_price, Length: 1834, dtype: float64

# %% [markdown]
# ## 3. What are the most popular 3 items?

# %%
df.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#    item_price
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98

# %%
df.groupby('item_name').quantity.sum().nlargest(3)
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Name: quantity, dtype: int64

# %% [markdown]
# ## 4. Which item has produced the most revenue?

# %%
df.groupby('item_name').item_price.agg('sum').sort_values(ascending=False)
# Out:
# item_name
# Chicken Bowl                             7342.73
# Chicken Burrito                          5575.82
# Steak Burrito                            3851.43
# Steak Bowl                               2260.19
# Chips and Guacamole                      2201.04
# Chicken Salad Bowl                       1228.75
# Chicken Soft Tacos                       1108.09
# Veggie Burrito                            934.77
# Barbacoa Burrito                          894.75
# Veggie Bowl                               867.99
# Carnitas Bowl                             736.71
# Barbacoa Bowl                             672.36
# Carnitas Burrito                          597.83
# Steak Soft Tacos                          536.05
# Chips                                     494.34
# Chicken Crispy Tacos                      472.13
# Canned Soft Drink                         438.75
# Carnitas Soft Tacos                       375.94
# Chips and Fresh Tomato Salsa              361.36
# Steak Crispy Tacos                        357.34
# 6 Pack Soft Drink                         356.95
# Steak Salad Bowl                          343.59
# Bottled Water                             302.56
# Barbacoa Soft Tacos                       250.46
# Side of Chips                             185.90
# Veggie Salad Bowl                         182.50
# Chips and Tomatillo Red Chili Salsa       147.50
# Canned Soda                               137.34
# Chips and Tomatillo Green Chili Salsa     132.75
# Barbacoa Crispy Tacos                     120.21
# Barbacoa Salad Bowl                       106.40
# Nantucket Nectar                           98.31
# Chicken Salad                              81.09
# Chips and Tomatillo-Green Chili Salsa      78.87
# Carnitas Crispy Tacos                      77.96
# Veggie Soft Tacos                          73.96
# Chips and Roasted Chili Corn Salsa         67.85
# Izze                                       67.80
# Carnitas Salad Bowl                        66.34
# Chips and Tomatillo-Red Chili Salsa        59.75
# Veggie Salad                               50.94
# Burrito                                    44.40
# Chips and Roasted Chili-Corn Salsa         43.02
# Steak Salad                                35.66
# Bowl                                       29.60
# Salad                                      14.80
# Crispy Tacos                               14.80
# Carnitas Salad                              8.99
# Veggie Crispy Tacos                         8.49
# Chips and Mild Fresh Tomato Salsa           3.00
# Name: item_price, dtype: float64

# %%
df.groupby('item_name').item_price.sum().nlargest(1)
# Out:
# item_name
# Chicken Bowl    7342.73
# Name: item_price, dtype: float64

# %% [markdown]
# ## 5. Join the employees and titles DataFrames together.

# %%
def get_db_url(db_name):
    from env import user, host, password
    return f'mysql+pymysql://{user}:{password}@{host}/{db_name}'

# %%
url = get_db_url('employees')
url
# Out:
# 'mysql+pymysql://hopper_1560:ZtQEG4UaEJjR8khD2h5h8A9OUwsMjMK0@157.230.209.171/employees'

# %%
sql = """
    SELECT * from employees
"""

# %%
df_employees = pd.read_sql(sql, url)
df_employees.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
sql = """
    SELECT * from titles
"""

# %%
df_titles = pd.read_sql(sql, url)
df_titles.head()
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01

# %%
df_emp_titles = df_employees.merge(df_titles, left_on='emp_no', right_on='emp_no')
df_emp_titles
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date
# 0       Senior Engineer  1986-06-26  9999-01-01
# 1                 Staff  1996-08-03  9999-01-01
# 2       Senior Engineer  1995-12-03  9999-01-01
# 3              Engineer  1986-12-01  1995-12-01
# 4       Senior Engineer  1995-12-01  9999-01-01
# ...                 ...         ...         ...
# 443303         Engineer  1987-08-30  1992-08-29
# 443304  Senior Engineer  1992-08-29  9999-01-01
# 443305     Senior Staff  1998-12-27  9999-01-01
# 443306            Staff  1993-12-27  1998-12-27
# 443307         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 9 columns]

# %% [markdown]
# ## 6. For each title, find the hire date of the employee that was hired most recently with that title?

# %%
df_emp_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 443308 entries, 0 to 443307
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      443308 non-null  int64
#  1   birth_date  443308 non-null  object
#  2   first_name  443308 non-null  object
#  3   last_name   443308 non-null  object
#  4   gender      443308 non-null  object
#  5   hire_date   443308 non-null  object
#  6   title       443308 non-null  object
#  7   from_date   443308 non-null  object
#  8   to_date     443308 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 33.8+ MB

# %%
df_emp_titles.hire_date = pd.to_datetime(df_emp_titles.hire_date)

# %%
df_emp_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 443308 entries, 0 to 443307
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      443308 non-null  int64
#  1   birth_date  443308 non-null  object
#  2   first_name  443308 non-null  object
#  3   last_name   443308 non-null  object
#  4   gender      443308 non-null  object
#  5   hire_date   443308 non-null  datetime64[ns]
#  6   title       443308 non-null  object
#  7   from_date   443308 non-null  object
#  8   to_date     443308 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 33.8+ MB

# %%
df_emp_titles.groupby('title').hire_date.nlargest(1)
# Out:
# title
# Assistant Engineer  212605   1999-12-24
# Engineer            389997   2000-01-28
# Manager             148155   1992-02-05
# Senior Engineer     145474   2000-01-01
# Senior Staff        182100   2000-01-13
# Staff               55137    2000-01-12
# Technique Leader    287947   1999-12-31
# Name: hire_date, dtype: datetime64[ns]

# %% [markdown]
# ## 7. Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)

# %%
url = get_db_url('employees')
url

# %%
sql = """
    SELECT * from departments
"""

# %%
df_departments = pd.read_sql(sql, url)
df_departments.head()
# Out:
#   dept_no         dept_name
# 0    d009  Customer Service
# 1    d005       Development
# 2    d002           Finance
# 3    d003   Human Resources
# 4    d001         Marketing

# %%
sql = """
    SELECT * from dept_emp
"""

# %%
df_dept_emp = pd.read_sql(sql, url)
df_dept_emp.head()
# Out:
#    emp_no dept_no   from_date     to_date
# 0   10001    d005  1986-06-26  9999-01-01
# 1   10002    d007  1996-08-03  9999-01-01
# 2   10003    d004  1995-12-03  9999-01-01
# 3   10004    d004  1986-12-01  9999-01-01
# 4   10005    d003  1989-09-12  9999-01-01

# %%
df_emp_titles
# Out:
#         emp_no  birth_date first_name last_name gender  hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M 1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F 1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M 1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M 1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M 1986-12-01
# ...        ...         ...        ...       ...    ...        ...
# 443303  499997  1961-08-03    Berhard    Lenart      M 1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M 1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M 1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M 1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M 1997-11-30
#
#                   title   from_date     to_date
# 0       Senior Engineer  1986-06-26  9999-01-01
# 1                 Staff  1996-08-03  9999-01-01
# 2       Senior Engineer  1995-12-03  9999-01-01
# 3              Engineer  1986-12-01  1995-12-01
# 4       Senior Engineer  1995-12-01  9999-01-01
# ...                 ...         ...         ...
# 443303         Engineer  1987-08-30  1992-08-29
# 443304  Senior Engineer  1992-08-29  9999-01-01
# 443305     Senior Staff  1998-12-27  9999-01-01
# 443306            Staff  1993-12-27  1998-12-27
# 443307         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 9 columns]

# %%
df_e_t_de = df_emp_titles.merge(df_dept_emp, left_on='emp_no', right_on='emp_no')
df_e_t_de
# Out:
#         emp_no  birth_date first_name last_name gender  hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M 1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F 1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M 1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M 1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M 1986-12-01
# ...        ...         ...        ...       ...    ...        ...
# 489898  499997  1961-08-03    Berhard    Lenart      M 1986-04-21
# 489899  499997  1961-08-03    Berhard    Lenart      M 1986-04-21
# 489900  499998  1956-09-05   Patricia   Breugel      M 1993-10-13
# 489901  499998  1956-09-05   Patricia   Breugel      M 1993-10-13
# 489902  499999  1958-05-01     Sachin   Tsukuda      M 1997-11-30
#
#                   title from_date_x   to_date_x dept_no from_date_y  \
# 0       Senior Engineer  1986-06-26  9999-01-01    d005  1986-06-26
# 1                 Staff  1996-08-03  9999-01-01    d007  1996-08-03
# 2       Senior Engineer  1995-12-03  9999-01-01    d004  1995-12-03
# 3              Engineer  1986-12-01  1995-12-01    d004  1986-12-01
# 4       Senior Engineer  1995-12-01  9999-01-01    d004  1986-12-01
# ...                 ...         ...         ...     ...         ...
# 489898         Engineer  1987-08-30  1992-08-29    d005  1987-08-30
# 489899  Senior Engineer  1992-08-29  9999-01-01    d005  1987-08-30
# 489900     Senior Staff  1998-12-27  9999-01-01    d002  1993-12-27
# 489901            Staff  1993-12-27  1998-12-27    d002  1993-12-27
# 489902         Engineer  1997-11-30  9999-01-01    d004  1997-11-30
#
#          to_date_y
# 0       9999-01-01
# 1       9999-01-01
# 2       9999-01-01
# 3       9999-01-01
# 4       9999-01-01
# ...            ...
# 489898  9999-01-01
# 489899  9999-01-01
# 489900  9999-01-01
# 489901  9999-01-01
# 489902  9999-01-01
#
# [489903 rows x 12 columns]

# %%
df_all = df_e_t_de.merge(df_departments, left_on='dept_no', right_on='dept_no')
df_all.head()
# Out:
#    emp_no  birth_date first_name  last_name gender  hire_date  \
# 0   10001  1953-09-02     Georgi    Facello      M 1986-06-26
# 1   10006  1953-04-20     Anneke    Preusig      F 1989-06-02
# 2   10008  1958-02-19     Saniya   Kalloufi      M 1994-09-15
# 3   10012  1960-10-04   Patricio  Bridgland      M 1992-12-18
# 4   10012  1960-10-04   Patricio  Bridgland      M 1992-12-18
#
#                 title from_date_x   to_date_x dept_no from_date_y   to_date_y  \
# 0     Senior Engineer  1986-06-26  9999-01-01    d005  1986-06-26  9999-01-01
# 1     Senior Engineer  1990-08-05  9999-01-01    d005  1990-08-05  9999-01-01
# 2  Assistant Engineer  1998-03-11  2000-07-31    d005  1998-03-11  2000-07-31
# 3            Engineer  1992-12-18  2000-12-18    d005  1992-12-18  9999-01-01
# 4     Senior Engineer  2000-12-18  9999-01-01    d005  1992-12-18  9999-01-01
#
#      dept_name
# 0  Development
# 1  Development
# 2  Development
# 3  Development
# 4  Development

# %%
df_all_tab = pd.crosstab(df_all.dept_name, df_all.title, margins=True).T
df_all_tab
# Out:
# dept_name           Customer Service  Development  Finance  Human Resources  \
# title
# Assistant Engineer               298         7769        0                0
# Engineer                        2362        58135        0                0
# Manager                            4            2        2                2
# Senior Engineer                 2027        49326        0                0
# Senior Staff                   13925         1247    12139            12274
# Staff                          16150         1424    13929            14342
# Technique Leader                 309         7683        0                0
# All                            35075       125586    26070            26618
#
# dept_name           Marketing  Production  Quality Management  Research  \
# title
# Assistant Engineer          0        6445                1831       378
# Engineer                    0       49649               13852      2986
# Manager                     2           4                   4         2
# Senior Engineer             0       42205               11864      2570
# Senior Staff            13940        1270                   0     11637
# Staff                   16196        1478                   0     13495
# Technique Leader            0        6557                1795       393
# All                     30138      107608               29346     31461
#
# dept_name           Sales     All
# title
# Assistant Engineer      0   16721
# Engineer                0  126984
# Manager                 2      24
# Senior Engineer         0  107992
# Senior Staff        36191  102623
# Staff               41808  118822
# Technique Leader        0   16737
# All                 78001  489903

# %%
df_all.groupby('dept_name').title.count()
# Out:
# dept_name
# Customer Service       35075
# Development           125586
# Finance                26070
# Human Resources        26618
# Marketing              30138
# Production            107608
# Quality Management     29346
# Research               31461
# Sales                  78001
# Name: title, dtype: int64
